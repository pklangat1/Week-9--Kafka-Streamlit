# %% [markdown]
# Apache Kafka and Streamlit exploration
# Wednesday 26-April Project Brief: Data Streaming with Kafka
# apache kafka
#
# Background: Telecommunications Mobile Money Data Engineering with Kafka
# In this project, you will work with telecommunications mobile money data to build a Kafka data engineering solution. You will be provided with a dummy json file containing sample data that you will use to test your solution.
#
# The project aims to build a Kafka pipeline that can receive real-time data from telecommunications mobile money transactions and process it for analysis. The pipeline should be designed to handle high volumes of data and ensure that the data is processed efficiently.
#
# To complete this project, you will need to follow these steps:
# 1. Set up a Kafka cluster: You must set up a Kafka cluster that can handle high volumes of data. You can use either a cloud-based or on-premises Kafka cluster.
# 2. Develop a Kafka producer: You must develop a Kafka producer that can ingest data from telecommunications mobile money transactions and send it to the Kafka cluster. The producer should be designed to handle high volumes of data and ensure that the data is sent to the Kafka cluster efficiently.
# 3. Develop a Kafka consumer: You must develop a Kafka consumer to receive data from the Kafka cluster and process it for analysis. The consumer should be designed to handle high volumes of data and ensure that the data is processed efficiently.
# 4. Process the data: Once you have set up the Kafka pipeline, you must process the data for analysis. This may involve cleaning and aggregating the data, performing calculations, and creating visualizations.
# 5. Test the solution: You must test your solution using the provided dummy json file. The file contains sample data that you can use to ensure that your Kafka pipeline is working correctly.
#
# Here’s the dummy JSON file that represents our mobile money data.
# {
# "transaction_id": "12345",
# "sender_phone_number": "256777123456",
# "receiver_phone_number": "256772987654",
# "transaction_amount": 100000,
# "transaction_time": "2023-04-19 12:00:00"
# }
#
# Steps to setup the pipeline
#
# 1- Goto https://confluent.cloud/ and setup a kafka cluster and topic
# 2- Get the connection details for your cluster instance
# 3- In the attached .py file find the code section with below entries. Update the below connection details to reflect the connection details generated for your own confluence cluster instance.
#
# bootstrap_servers = '#YOUR_URL#.confluent.cloud:9092'
# security_protocol = 'SASL_SSL'
# sasl_mechanism = 'PLAIN'
# sasl_plain_username = '#YOUR_USERNAME#'
# sasl_plain_password = '#YOUR_PASSWORD#'
# topic = 'my_pipeline'
#
# 4- Run the .py file to start the streaming pipeline
#
# ========================================================================================

# %%
#Install confluent library
# !pip install confluent-kafka
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 26.5 MB/s eta 0:00:00
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.1.1

# %%
#Import needed libraries
from confluent_kafka import Producer, Consumer
import json
from collections import defaultdict
from collections import OrderedDict

import random
import json
from datetime import datetime
import time
from tabulate import tabulate

import logging
#Setup logger
logging.basicConfig(filename='pipeline.log', level=logging.DEBUG)

# %%
# Kafka Confluent Cloud configurations parameters

bootstrap_servers = 'pkc-lzvrd.us-west4.gcp.confluent.cloud:9092'
security_protocol = 'SASL_SSL'
sasl_mechanism = 'PLAIN'
sasl_plain_username = '55KQYATTLVSWUKUI'
sasl_plain_password = '9bNSfTUILIbMwmlTcRFs6JRDNy7Kjenf77A9NlC3mxEAjf7unXIJOA2hk1OiQn6B'
topic = 'my_pipeline'

# Producer config
producer_conf = {
    'bootstrap.servers': bootstrap_servers,
    'security.protocol': security_protocol,
    'sasl.mechanism': sasl_mechanism,
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password
}

# Consumer config
consumer_conf = {
    'bootstrap.servers': bootstrap_servers,
    'security.protocol': security_protocol,
    'sasl.mechanism': sasl_mechanism,
    'sasl.username': sasl_plain_username,
    'sasl.password': sasl_plain_password,
    'group.id': 'my_consumer_group'
}

"""Using below sample template to generate random data values:
{<br>
"transaction_id": "12345",<br>
"sender_phone_number": "256777123456",<br>
"receiver_phone_number": "256772987654",<br>
"transaction_amount": 100000,<br>
"transaction_time": "2023-04-19 12:00:00"<br>
}
"""

#Function to excute the supplied text

def border1(text):

  """
    Function used to draw the grid outline on cli output using tabulate library
  """
  table = [[text]]
  output = tabulate(table, tablefmt='grid')
  print(output)


def border2(text):

  """
    Function used to draw the fancy_grid outline upon loop exit using tabulate library
  """
  table = [[text]]
  output = tabulate(table, tablefmt='fancy_grid')
  print(output)

#Producer config

producer = Producer(producer_conf)


def json_generator():

  """
  Function generates random customer data for producer to load to topic hosted on confluent cloud
  """
  x=0   #a loop counter
  dict_list = []

  try:
    while x<5:
        # Generate random transaction ID
        transaction_id = str(random.randint(10000, 99999))

        # Generate random phone numbers
        sender_phone_number = "256" + "".join(str(random.randint(0, 9)) for _ in range(9))
        receiver_phone_number = "256" + "".join(str(random.randint(0, 9)) for _ in range(9))

        # Generate random transaction amount
        transaction_amount = random.randint(1, 100000)

        # Generate random transaction time
        transaction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        # Create the JSON object
        data = {
            "transaction_id": transaction_id,
            "sender_phone_number": sender_phone_number,
            "receiver_phone_number": receiver_phone_number,
            "transaction_amount": transaction_amount,
            "transaction_time": transaction_time
        }

        dict_list.append(data)
        x=x+1

        #sleep 1 second so that timestamp values vary
        time.sleep(1)
        
    
    # Produce sample CDR data to Kafka topic
    for trx in dict_list:
      # Serialize transaction data to JSON
      serialized_trx = json.dumps(trx).encode('utf-8')
      # Produce message to Kafka topic
      producer.produce(topic, key=None, value=serialized_trx)
      producer.flush()

    print('Producer posted sample transaction data to Kafka topic....')

  except Exception as e:
    err = "Producer() error - "+str(e)
    logging.debug(err)

# Create the Kafka consumer
consumer = Consumer(consumer_conf)

# Subscribe to the topic
consumer.subscribe([topic])

#The _main-pipeline_ function

def main_pipeline():

  """
  Main pipeline function that starts by producing and posting to the topic | It then enters a while loop where consumer reads messages from topic, this message data is used to analyse customer transaction spend/
  unique sender/unique recipient/ max spend/ min spend. Running stats are posted in realtime as each message is consumed
  """

  # Variables to store data
  transaction_count = 0
  total_transaction_amount = 0
  transaction_amount_histogram = defaultdict(int)
  trx_amount_tracker = {}
  unique_sender_numbers = set()
  unique_receiver_numbers = set()
  
  #produce some data first...
  json_generator()

  try:
      print("Pipeline 'While' loop started.... Use Stop[on jupyter] or Ctrl+C[in bash] to stop the loop \n")
      while True:
      
          msg = consumer.poll(1.0)

          if msg is None:
              json_generator()
              continue

          if msg.error():
              print("Consumer error: {}".format(msg.error()))
              continue

          # Process the consumed message
          message = json.loads(msg.value())
          trx_amount_tracker[message.get('transaction_id')] = int(message.get('transaction_amount'))
          transaction_amount = int(message.get('transaction_amount'))
          sender_phone_number = message.get('sender_phone_number')
          receiver_phone_number = message.get('receiver_phone_number')

          # Update tracker data
          total_transaction_amount += transaction_amount
          transaction_count += 1
          transaction_amount_histogram[transaction_amount] += 1
          unique_sender_numbers.add(sender_phone_number)
          unique_receiver_numbers.add(receiver_phone_number)

          # Print the processed/consumed message
          border1("\nProcessed Message:"+json.dumps(message, indent=4))
          print("")

          # Print the aggregated data
          print("Total of all transactions[Kshs]: ", total_transaction_amount)
          
          print("Top 5 transaction amounts table:\n")
          sorted_items = dict(sorted(trx_amount_tracker.items(),  key=lambda x: x[1], reverse=True)[:5])  
          for key,value in sorted_items.items():
                print(f"Trx amount [Kshs]: {value}: Trx ID: {key}")

          # Find the largest and smallest trx spend amount values 
          largest_value = max(trx_amount_tracker.values())
          smallest_value = min(trx_amount_tracker.values())
          # Find the corresponding keys for min, max...
          largest_keys = [key for key, value in trx_amount_tracker.items() if value == largest_value]
          smallest_keys = [key for key, value in trx_amount_tracker.items() if value == smallest_value]

          # Print the largest and smallest keys and values
          for trx in largest_keys:
            print(f"\nLargest trx amounts. Trx ID {trx} - Amount {trx_amount_tracker[trx]}")

          for trx in smallest_keys:
            print(f"Smallest trx amounts. Trx ID {trx} - Amount {trx_amount_tracker[trx]} \n")
          

          print("Number of Unique Sender Phone Numbers:", len(unique_sender_numbers))
          print("Number of Unique Receiver Phone Numbers:", len(unique_receiver_numbers))
         

  except KeyboardInterrupt:
      pass

  finally:
      border2("Loop exit - Finally...closing the consumer...")

  #close the consumer()
  consumer.close()

if __name__ == '__main__':
    # Run the data pipeline function
    main_pipeline()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 29
# Number of Unique Receiver Phone Numbers: 29
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "57801",                |
# |     "sender_phone_number": "256493293894",    |
# |     "receiver_phone_number": "256672639159",  |
# |     "transaction_amount": 19023,              |
# |     "transaction_time": "2023-05-18 05:28:55" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1452948
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 30
# Number of Unique Receiver Phone Numbers: 30
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "39284",                |
# |     "sender_phone_number": "256419601524",    |
# |     "receiver_phone_number": "256639675160",  |
# |     "transaction_amount": 18699,              |
# |     "transaction_time": "2023-05-18 05:28:58" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1471647
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 31
# Number of Unique Receiver Phone Numbers: 31
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "92507",                |
# |     "sender_phone_number": "256511732936",    |
# |     "receiver_phone_number": "256242621843",  |
# |     "transaction_amount": 50735,              |
# |     "transaction_time": "2023-05-18 05:28:59" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1522382
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 32
# Number of Unique Receiver Phone Numbers: 32
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "87009",                |
# |     "sender_phone_number": "256035846106",    |
# |     "receiver_phone_number": "256702050144",  |
# |     "transaction_amount": 68116,              |
# |     "transaction_time": "2023-05-18 05:29:00" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1590498
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 33
# Number of Unique Receiver Phone Numbers: 33
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "85941",                |
# |     "sender_phone_number": "256256713942",    |
# |     "receiver_phone_number": "256617413756",  |
# |     "transaction_amount": 48661,              |
# |     "transaction_time": "2023-05-18 05:29:01" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1639159
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
# Trx amount [Kshs]: 86398: Trx ID: 54958
#
# Largest trx amounts. Trx ID 88393 - Amount 97860
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 34
# Number of Unique Receiver Phone Numbers: 34
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "49526",                |
# |     "sender_phone_number": "256085853491",    |
# |     "receiver_phone_number": "256721308104",  |
# |     "transaction_amount": 99588,              |
# |     "transaction_time": "2023-05-18 05:29:02" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1738747
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 35
# Number of Unique Receiver Phone Numbers: 35
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "58215",                |
# |     "sender_phone_number": "256579996385",    |
# |     "receiver_phone_number": "256443882926",  |
# |     "transaction_amount": 79566,              |
# |     "transaction_time": "2023-05-18 05:29:05" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1818313
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
# Trx amount [Kshs]: 89288: Trx ID: 36005
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 36
# Number of Unique Receiver Phone Numbers: 36
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "85589",                |
# |     "sender_phone_number": "256885643869",    |
# |     "receiver_phone_number": "256629000026",  |
# |     "transaction_amount": 96208,              |
# |     "transaction_time": "2023-05-18 05:29:06" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  1914521
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 89887: Trx ID: 12002
# Trx amount [Kshs]: 89828: Trx ID: 42555
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 37
# Number of Unique Receiver Phone Numbers: 37
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "31680",                |
# |     "sender_phone_number": "256316707037",    |
# |     "receiver_phone_number": "256115581862",  |
# |     "transaction_amount": 90637,              |
# |     "transaction_time": "2023-05-18 05:29:07" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2005158
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 38
# Number of Unique Receiver Phone Numbers: 38
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "97261",                |
# |     "sender_phone_number": "256131354078",    |
# |     "receiver_phone_number": "256933611991",  |
# |     "transaction_amount": 65279,              |
# |     "transaction_time": "2023-05-18 05:29:08" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2070437
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 39
# Number of Unique Receiver Phone Numbers: 39
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "66552",                |
# |     "sender_phone_number": "256838271773",    |
# |     "receiver_phone_number": "256124314087",  |
# |     "transaction_amount": 27104,              |
# |     "transaction_time": "2023-05-18 05:29:09" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2097541
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 40
# Number of Unique Receiver Phone Numbers: 40
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "15083",                |
# |     "sender_phone_number": "256964947544",    |
# |     "receiver_phone_number": "256789636118",  |
# |     "transaction_amount": 89216,              |
# |     "transaction_time": "2023-05-18 05:29:12" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2186757
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 41
# Number of Unique Receiver Phone Numbers: 41
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "17019",                |
# |     "sender_phone_number": "256226021648",    |
# |     "receiver_phone_number": "256584989359",  |
# |     "transaction_amount": 84172,              |
# |     "transaction_time": "2023-05-18 05:29:13" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2270929
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 42
# Number of Unique Receiver Phone Numbers: 42
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "58285",                |
# |     "sender_phone_number": "256400468933",    |
# |     "receiver_phone_number": "256539470898",  |
# |     "transaction_amount": 6842,               |
# |     "transaction_time": "2023-05-18 05:29:14" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2277771
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 43
# Number of Unique Receiver Phone Numbers: 43
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "49918",                |
# |     "sender_phone_number": "256964149092",    |
# |     "receiver_phone_number": "256705807783",  |
# |     "transaction_amount": 60737,              |
# |     "transaction_time": "2023-05-18 05:29:15" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2338508
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 44
# Number of Unique Receiver Phone Numbers: 44
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "83169",                |
# |     "sender_phone_number": "256038572897",    |
# |     "receiver_phone_number": "256672682129",  |
# |     "transaction_amount": 64790,              |
# |     "transaction_time": "2023-05-18 05:29:16" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2403298
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 45
# Number of Unique Receiver Phone Numbers: 45
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "50607",                |
# |     "sender_phone_number": "256504025399",    |
# |     "receiver_phone_number": "256150318752",  |
# |     "transaction_amount": 79691,              |
# |     "transaction_time": "2023-05-18 05:29:18" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2482989
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 46
# Number of Unique Receiver Phone Numbers: 46
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "77710",                |
# |     "sender_phone_number": "256761237541",    |
# |     "receiver_phone_number": "256631081372",  |
# |     "transaction_amount": 62844,              |
# |     "transaction_time": "2023-05-18 05:29:19" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2545833
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 47
# Number of Unique Receiver Phone Numbers: 47
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "84539",                |
# |     "sender_phone_number": "256594739837",    |
# |     "receiver_phone_number": "256592712926",  |
# |     "transaction_amount": 35957,              |
# |     "transaction_time": "2023-05-18 05:29:20" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2581790
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 48
# Number of Unique Receiver Phone Numbers: 48
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "61811",                |
# |     "sender_phone_number": "256990755004",    |
# |     "receiver_phone_number": "256581484096",  |
# |     "transaction_amount": 42164,              |
# |     "transaction_time": "2023-05-18 05:29:21" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2623954
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 49
# Number of Unique Receiver Phone Numbers: 49
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "50464",                |
# |     "sender_phone_number": "256813361238",    |
# |     "receiver_phone_number": "256937265662",  |
# |     "transaction_amount": 61907,              |
# |     "transaction_time": "2023-05-18 05:29:22" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2685861
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 50
# Number of Unique Receiver Phone Numbers: 50
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "73802",                |
# |     "sender_phone_number": "256058952580",    |
# |     "receiver_phone_number": "256402454042",  |
# |     "transaction_amount": 27575,              |
# |     "transaction_time": "2023-05-18 05:29:25" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2713436
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 51
# Number of Unique Receiver Phone Numbers: 51
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "54258",                |
# |     "sender_phone_number": "256936755934",    |
# |     "receiver_phone_number": "256844483606",  |
# |     "transaction_amount": 89303,              |
# |     "transaction_time": "2023-05-18 05:29:26" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2802739
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 52
# Number of Unique Receiver Phone Numbers: 52
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "60401",                |
# |     "sender_phone_number": "256257063905",    |
# |     "receiver_phone_number": "256147667939",  |
# |     "transaction_amount": 72578,              |
# |     "transaction_time": "2023-05-18 05:29:27" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2875317
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 53
# Number of Unique Receiver Phone Numbers: 53
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "54535",                |
# |     "sender_phone_number": "256183464830",    |
# |     "receiver_phone_number": "256466788526",  |
# |     "transaction_amount": 76083,              |
# |     "transaction_time": "2023-05-18 05:29:28" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  2951400
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 54
# Number of Unique Receiver Phone Numbers: 54
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "58705",                |
# |     "sender_phone_number": "256966164708",    |
# |     "receiver_phone_number": "256445910755",  |
# |     "transaction_amount": 67024,              |
# |     "transaction_time": "2023-05-18 05:29:29" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3018424
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 55
# Number of Unique Receiver Phone Numbers: 55
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "37184",                |
# |     "sender_phone_number": "256813903930",    |
# |     "receiver_phone_number": "256765623076",  |
# |     "transaction_amount": 3719,               |
# |     "transaction_time": "2023-05-18 05:29:32" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3022143
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 56
# Number of Unique Receiver Phone Numbers: 56
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "69591",                |
# |     "sender_phone_number": "256199700697",    |
# |     "receiver_phone_number": "256383594182",  |
# |     "transaction_amount": 58035,              |
# |     "transaction_time": "2023-05-18 05:29:33" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3080178
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 57
# Number of Unique Receiver Phone Numbers: 57
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "57039",                |
# |     "sender_phone_number": "256993254963",    |
# |     "receiver_phone_number": "256460510423",  |
# |     "transaction_amount": 37472,              |
# |     "transaction_time": "2023-05-18 05:29:34" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3117650
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 58
# Number of Unique Receiver Phone Numbers: 58
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "99796",                |
# |     "sender_phone_number": "256706896370",    |
# |     "receiver_phone_number": "256561356975",  |
# |     "transaction_amount": 67138,              |
# |     "transaction_time": "2023-05-18 05:29:35" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3184788
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
# Trx amount [Kshs]: 89887: Trx ID: 12002
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 59
# Number of Unique Receiver Phone Numbers: 59
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "26094",                |
# |     "sender_phone_number": "256246761820",    |
# |     "receiver_phone_number": "256007946347",  |
# |     "transaction_amount": 97510,              |
# |     "transaction_time": "2023-05-18 05:29:36" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3282298
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 60
# Number of Unique Receiver Phone Numbers: 60
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "59654",                |
# |     "sender_phone_number": "256532447269",    |
# |     "receiver_phone_number": "256754934243",  |
# |     "transaction_amount": 43271,              |
# |     "transaction_time": "2023-05-18 05:29:39" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3325569
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 61
# Number of Unique Receiver Phone Numbers: 61
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "58451",                |
# |     "sender_phone_number": "256859886320",    |
# |     "receiver_phone_number": "256197792355",  |
# |     "transaction_amount": 71140,              |
# |     "transaction_time": "2023-05-18 05:29:40" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3396709
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 62
# Number of Unique Receiver Phone Numbers: 62
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "17354",                |
# |     "sender_phone_number": "256403243395",    |
# |     "receiver_phone_number": "256057258705",  |
# |     "transaction_amount": 17393,              |
# |     "transaction_time": "2023-05-18 05:29:41" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3414102
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 63
# Number of Unique Receiver Phone Numbers: 63
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "49821",                |
# |     "sender_phone_number": "256591202892",    |
# |     "receiver_phone_number": "256674749484",  |
# |     "transaction_amount": 54870,              |
# |     "transaction_time": "2023-05-18 05:29:42" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3468972
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 64
# Number of Unique Receiver Phone Numbers: 64
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "28554",                |
# |     "sender_phone_number": "256274760427",    |
# |     "receiver_phone_number": "256634444924",  |
# |     "transaction_amount": 28240,              |
# |     "transaction_time": "2023-05-18 05:29:43" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3497212
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 65
# Number of Unique Receiver Phone Numbers: 65
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "41052",                |
# |     "sender_phone_number": "256924816016",    |
# |     "receiver_phone_number": "256663391154",  |
# |     "transaction_amount": 68045,              |
# |     "transaction_time": "2023-05-18 05:29:46" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3565257
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 90637: Trx ID: 31680
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 66
# Number of Unique Receiver Phone Numbers: 66
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "24519",                |
# |     "sender_phone_number": "256714795629",    |
# |     "receiver_phone_number": "256194600823",  |
# |     "transaction_amount": 92749,              |
# |     "transaction_time": "2023-05-18 05:29:47" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3658006
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 67
# Number of Unique Receiver Phone Numbers: 67
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "34718",                |
# |     "sender_phone_number": "256772603644",    |
# |     "receiver_phone_number": "256077649346",  |
# |     "transaction_amount": 52068,              |
# |     "transaction_time": "2023-05-18 05:29:48" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3710074
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 68
# Number of Unique Receiver Phone Numbers: 68
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "48875",                |
# |     "sender_phone_number": "256137198485",    |
# |     "receiver_phone_number": "256828972990",  |
# |     "transaction_amount": 30128,              |
# |     "transaction_time": "2023-05-18 05:29:49" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3740202
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 69
# Number of Unique Receiver Phone Numbers: 69
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "27752",                |
# |     "sender_phone_number": "256792801057",    |
# |     "receiver_phone_number": "256857757199",  |
# |     "transaction_amount": 12380,              |
# |     "transaction_time": "2023-05-18 05:29:50" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3752582
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 70
# Number of Unique Receiver Phone Numbers: 70
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "36409",                |
# |     "sender_phone_number": "256540940277",    |
# |     "receiver_phone_number": "256912444073",  |
# |     "transaction_amount": 67342,              |
# |     "transaction_time": "2023-05-18 05:29:52" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3819924
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 71
# Number of Unique Receiver Phone Numbers: 71
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "61392",                |
# |     "sender_phone_number": "256030941053",    |
# |     "receiver_phone_number": "256857495440",  |
# |     "transaction_amount": 83839,              |
# |     "transaction_time": "2023-05-18 05:29:53" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3903763
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 89995 - Amount 2674
#
# Number of Unique Sender Phone Numbers: 72
# Number of Unique Receiver Phone Numbers: 72
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "12833",                |
# |     "sender_phone_number": "256232461455",    |
# |     "receiver_phone_number": "256615552220",  |
# |     "transaction_amount": 1968,               |
# |     "transaction_time": "2023-05-18 05:29:54" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3905731
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 73
# Number of Unique Receiver Phone Numbers: 73
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "67913",                |
# |     "sender_phone_number": "256138282478",    |
# |     "receiver_phone_number": "256173587774",  |
# |     "transaction_amount": 7908,               |
# |     "transaction_time": "2023-05-18 05:29:55" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3913639
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 74
# Number of Unique Receiver Phone Numbers: 74
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "49745",                |
# |     "sender_phone_number": "256207015606",    |
# |     "receiver_phone_number": "256460044146",  |
# |     "transaction_amount": 5935,               |
# |     "transaction_time": "2023-05-18 05:29:56" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3919574
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 75
# Number of Unique Receiver Phone Numbers: 75
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "53219",                |
# |     "sender_phone_number": "256857660059",    |
# |     "receiver_phone_number": "256139624444",  |
# |     "transaction_amount": 68594,              |
# |     "transaction_time": "2023-05-18 05:29:59" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  3988168
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 76
# Number of Unique Receiver Phone Numbers: 76
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "60874",                |
# |     "sender_phone_number": "256327134952",    |
# |     "receiver_phone_number": "256787890811",  |
# |     "transaction_amount": 51045,              |
# |     "transaction_time": "2023-05-18 05:30:00" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  4039213
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 77
# Number of Unique Receiver Phone Numbers: 77
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "25534",                |
# |     "sender_phone_number": "256609198094",    |
# |     "receiver_phone_number": "256437656673",  |
# |     "transaction_amount": 7915,               |
# |     "transaction_time": "2023-05-18 05:30:01" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  4047128
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 78
# Number of Unique Receiver Phone Numbers: 78
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "86031",                |
# |     "sender_phone_number": "256786643748",    |
# |     "receiver_phone_number": "256768886604",  |
# |     "transaction_amount": 15496,              |
# |     "transaction_time": "2023-05-18 05:30:02" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  4062624
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 79
# Number of Unique Receiver Phone Numbers: 79
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "79332",                |
# |     "sender_phone_number": "256430640103",    |
# |     "receiver_phone_number": "256222800047",  |
# |     "transaction_amount": 33406,              |
# |     "transaction_time": "2023-05-18 05:30:03" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  4096030
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 97860: Trx ID: 88393
# Trx amount [Kshs]: 97510: Trx ID: 26094
# Trx amount [Kshs]: 96208: Trx ID: 85589
# Trx amount [Kshs]: 92749: Trx ID: 24519
#
# Largest trx amounts. Trx ID 49526 - Amount 99588
# Smallest trx amounts. Trx ID 12833 - Amount 1968
#
# Number of Unique Sender Phone Numbers: 80
# Number of Unique Receiver Phone Numbers: 80
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "50874",                |
# |     "sender_phone_number": "256176841930",    |
# |     "receiver_phone_number": "256083557997",  |
# ...
#
# Number of Unique Sender Phone Numbers: 218
# Number of Unique Receiver Phone Numbers: 218
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "12725",                |
# |     "sender_phone_number": "256003067365",    |
# |     "receiver_phone_number": "256659822214",  |
# |     "transaction_amount": 12012,              |
# |     "transaction_time": "2023-05-18 05:33:13" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  10885090
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 45342 - Amount 540
#
# Number of Unique Sender Phone Numbers: 219
# Number of Unique Receiver Phone Numbers: 219
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "74952",                |
# |     "sender_phone_number": "256127403259",    |
# |     "receiver_phone_number": "256540910595",  |
# |     "transaction_amount": 87509,              |
# |     "transaction_time": "2023-05-18 05:33:14" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  10972599
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 45342 - Amount 540
#
# Number of Unique Sender Phone Numbers: 220
# Number of Unique Receiver Phone Numbers: 220
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "88221",                |
# |     "sender_phone_number": "256746422930",    |
# |     "receiver_phone_number": "256575013750",  |
# |     "transaction_amount": 23544,              |
# |     "transaction_time": "2023-05-18 05:33:17" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  10996143
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 45342 - Amount 540
#
# Number of Unique Sender Phone Numbers: 221
# Number of Unique Receiver Phone Numbers: 221
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "32408",                |
# |     "sender_phone_number": "256846591228",    |
# |     "receiver_phone_number": "256354811026",  |
# |     "transaction_amount": 80106,              |
# |     "transaction_time": "2023-05-18 05:33:18" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11076249
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 45342 - Amount 540
#
# Number of Unique Sender Phone Numbers: 222
# Number of Unique Receiver Phone Numbers: 222
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "85090",                |
# |     "sender_phone_number": "256473130862",    |
# |     "receiver_phone_number": "256080666443",  |
# |     "transaction_amount": 280,                |
# |     "transaction_time": "2023-05-18 05:33:19" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11076529
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 223
# Number of Unique Receiver Phone Numbers: 223
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "88162",                |
# |     "sender_phone_number": "256271857290",    |
# |     "receiver_phone_number": "256734963178",  |
# |     "transaction_amount": 13109,              |
# |     "transaction_time": "2023-05-18 05:33:20" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11089638
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 224
# Number of Unique Receiver Phone Numbers: 224
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "85322",                |
# |     "sender_phone_number": "256901687095",    |
# |     "receiver_phone_number": "256035433144",  |
# |     "transaction_amount": 52014,              |
# |     "transaction_time": "2023-05-18 05:33:21" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11141652
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 225
# Number of Unique Receiver Phone Numbers: 225
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "30799",                |
# |     "sender_phone_number": "256937635823",    |
# |     "receiver_phone_number": "256739373071",  |
# |     "transaction_amount": 45636,              |
# |     "transaction_time": "2023-05-18 05:33:24" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11187288
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 226
# Number of Unique Receiver Phone Numbers: 226
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "32037",                |
# |     "sender_phone_number": "256960354233",    |
# |     "receiver_phone_number": "256200058657",  |
# |     "transaction_amount": 22101,              |
# |     "transaction_time": "2023-05-18 05:33:25" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11209389
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 227
# Number of Unique Receiver Phone Numbers: 227
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "27727",                |
# |     "sender_phone_number": "256633303826",    |
# |     "receiver_phone_number": "256348342816",  |
# |     "transaction_amount": 88122,              |
# |     "transaction_time": "2023-05-18 05:33:26" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11297511
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 228
# Number of Unique Receiver Phone Numbers: 228
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "23158",                |
# |     "sender_phone_number": "256871925887",    |
# |     "receiver_phone_number": "256291099430",  |
# |     "transaction_amount": 88222,              |
# |     "transaction_time": "2023-05-18 05:33:27" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11385733
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 229
# Number of Unique Receiver Phone Numbers: 229
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "71875",                |
# |     "sender_phone_number": "256061144250",    |
# |     "receiver_phone_number": "256743815983",  |
# |     "transaction_amount": 18212,              |
# |     "transaction_time": "2023-05-18 05:33:28" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11403945
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 230
# Number of Unique Receiver Phone Numbers: 230
# Producer posted sample transaction data to Kafka topic....
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "64616",                |
# |     "sender_phone_number": "256724654677",    |
# |     "receiver_phone_number": "256588498346",  |
# |     "transaction_amount": 57425,              |
# |     "transaction_time": "2023-05-18 05:33:30" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11461370
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 231
# Number of Unique Receiver Phone Numbers: 231
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "99438",                |
# |     "sender_phone_number": "256688730366",    |
# |     "receiver_phone_number": "256334527405",  |
# |     "transaction_amount": 34601,              |
# |     "transaction_time": "2023-05-18 05:33:31" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11495971
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 232
# Number of Unique Receiver Phone Numbers: 232
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "51945",                |
# |     "sender_phone_number": "256942544375",    |
# |     "receiver_phone_number": "256714938268",  |
# |     "transaction_amount": 27367,              |
# |     "transaction_time": "2023-05-18 05:33:32" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11523338
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 233
# Number of Unique Receiver Phone Numbers: 233
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "42148",                |
# |     "sender_phone_number": "256939039847",    |
# |     "receiver_phone_number": "256405720547",  |
# |     "transaction_amount": 67353,              |
# |     "transaction_time": "2023-05-18 05:33:33" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11590691
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 234
# Number of Unique Receiver Phone Numbers: 234
# +-----------------------------------------------+
# | Processed Message:{                           |
# |     "transaction_id": "10787",                |
# |     "sender_phone_number": "256328970384",    |
# |     "receiver_phone_number": "256451323962",  |
# |     "transaction_amount": 70747,              |
# |     "transaction_time": "2023-05-18 05:33:34" |
# | }                                             |
# +-----------------------------------------------+
#
# Total of all transactions[Kshs]:  11661438
# Top 5 transaction amounts table:
#
# Trx amount [Kshs]: 99977: Trx ID: 85771
# Trx amount [Kshs]: 99884: Trx ID: 43424
# Trx amount [Kshs]: 99588: Trx ID: 49526
# Trx amount [Kshs]: 99019: Trx ID: 90253
# Trx amount [Kshs]: 98910: Trx ID: 33974
#
# Largest trx amounts. Trx ID 85771 - Amount 99977
# Smallest trx amounts. Trx ID 85090 - Amount 280
#
# Number of Unique Sender Phone Numbers: 235
# Number of Unique Receiver Phone Numbers: 235
# ╒═══════════════════════════════════════════════╕
# │ Loop exit - Finally...closing the consumer... │
# ╘═══════════════════════════════════════════════╛
